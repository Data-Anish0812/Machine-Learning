# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df=pd.read_csv("USA_Housing (1).csv")

# %%
df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                             4.09     23086.800503  1.059034e+06
# 1                             3.09     40173.072174  1.505891e+06
# 2                             5.13     36882.159400  1.058988e+06
# 3                             3.26     34310.242831  1.260617e+06
# 4                             4.23     26354.109472  6.309435e+05
# ...                            ...              ...           ...
# 4995                          3.46     22837.361035  1.060194e+06
# 4996                          4.02     25616.115489  1.482618e+06
# 4997                          2.13     33266.145490  1.030730e+06
# 4998                          5.44     42625.620156  1.198657e+06
# 4999                          4.07     46501.283803  1.298950e+06
#
#                                                 Address
# 0     208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1     188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2     9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3                             USS Barnett\nFPO AP 44820
# 4                            USNS Raymond\nFPO AE 09386
# ...                                                 ...
# 4995                   USNS Williams\nFPO AP 30153-7653
# 4996              PSC 9258, Box 8489\nAPO AA 42991-3352
# 4997  4215 Tracy Garden Suite 076\nJoshualand, VA 01...
# 4998                          USS Wallace\nFPO AE 73316
# 4999  37778 George Ridges Apt. 509\nEast Holly, NV 2...
#
# [5000 rows x 7 columns]

# %%
df=df.drop('Address',axis=1)

# %%
df.isnull().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# dtype: int64

# %%
df.dtypes
# Out:
# Avg. Area Income                float64
# Avg. Area House Age             float64
# Avg. Area Number of Rooms       float64
# Avg. Area Number of Bedrooms    float64
# Area Population                 float64
# Price                           float64
# dtype: object

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# min                        2.000000       172.610686  1.593866e+04
# 25%                        3.140000     29403.928702  9.975771e+05
# 50%                        4.050000     36199.406689  1.232669e+06
# 75%                        4.490000     42861.290769  1.471210e+06
# max                        6.500000     69621.713378  2.469066e+06

# %%
df.corr()
# Out:
#                               Avg. Area Income  Avg. Area House Age  \
# Avg. Area Income                      1.000000            -0.002007
# Avg. Area House Age                  -0.002007             1.000000
# Avg. Area Number of Rooms            -0.011032            -0.009428
# Avg. Area Number of Bedrooms          0.019788             0.006149
# Area Population                      -0.016234            -0.018743
# Price                                 0.639734             0.452543
#
#                               Avg. Area Number of Rooms  \
# Avg. Area Income                              -0.011032
# Avg. Area House Age                           -0.009428
# Avg. Area Number of Rooms                      1.000000
# Avg. Area Number of Bedrooms                   0.462695
# Area Population                                0.002040
# Price                                          0.335664
#
#                               Avg. Area Number of Bedrooms  Area Population  \
# Avg. Area Income                                  0.019788        -0.016234
# Avg. Area House Age                               0.006149        -0.018743
# Avg. Area Number of Rooms                         0.462695         0.002040
# Avg. Area Number of Bedrooms                      1.000000        -0.022168
# Area Population                                  -0.022168         1.000000
# Price                                             0.171071         0.408556
#
#                                  Price
# Avg. Area Income              0.639734
# Avg. Area House Age           0.452543
# Avg. Area Number of Rooms     0.335664
# Avg. Area Number of Bedrooms  0.171071
# Area Population               0.408556
# Price                         1.000000

# %%
df['Income Bin'] = pd.cut(df['Avg. Area Income'], bins=5)
sns.barplot(x='Income Bin', y='Price', data=df)
plt.title('Average Price by Income Bin')
plt.xticks(rotation=45)
plt.show()

# %%
sns.histplot(df['Price'], kde=True)
plt.title('Distribution of House Prices')
plt.show()

# %%
sns.displot(df['Avg. Area House Age'], kde=True)
plt.title('Distribution of House Age')
plt.show()

# %%
sns.kdeplot(df['Price'], shade=True)
plt.title('KDE Plot of House Prices')
plt.show()
# Out:
# C:\Users\anish\AppData\Local\Temp\ipykernel_17344\1165091888.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Price'], shade=True)

# %%
price_bins = pd.cut(df['Price'], bins=4)
price_distribution = price_bins.value_counts()
price_distribution.plot.pie(autopct='%1.1f%%')
plt.title('Price Distribution')
plt.ylabel('')
plt.show()

# %%
sns.scatterplot(x='Avg. Area Income', y='Price', data=df)
plt.title('Price vs. Avg. Area Income')
plt.show()

# %%
sns.pairplot(df[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms', 'Price']])
plt.show()

# %%
corr_matrix = df[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms', 'Avg. Area Number of Bedrooms', 'Price']].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()
#when we are near 0 correlation is there research should be focused on that and whereas number which are 0 or -1 are less important

# %%
df['Price Bin'] = pd.cut(df['Price'], bins=5)
price_grouped = df.groupby('Price Bin')[['Avg. Area Number of Rooms', 'Avg. Area Number of Bedrooms', 'Avg. Area House Age', 'Avg. Area Income']].mean()

price_grouped.plot(kind='bar', figsize=(12, 7))
plt.title('Average Features by Price Bin')
plt.xlabel('Price Bin')
plt.ylabel('Average Value')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\anish\AppData\Local\Temp\ipykernel_17344\2488360811.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   price_grouped = df.groupby('Price Bin')[['Avg. Area Number of Rooms', 'Avg. Area Number of Bedrooms', 'Avg. Area House Age', 'Avg. Area Income']].mean()

# %%
# Bin the 'Avg. Area Income' into 4 categories
df['Income Bin'] = pd.cut(df['Avg. Area Income'], bins=4)

# Bin the 'Avg. Area House Age' into 4 categories
df['Age Bin'] = pd.cut(df['Avg. Area House Age'], bins=4)

# Violin Plot comparing 'Price' by binned 'Income' and 'Age'
sns.violinplot(x='Income Bin', y='Price', hue='Age Bin', data=df, split=True)
plt.title('Price Distribution by Income and House Age Bins')
plt.xlabel('Income Bin')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()

# %%
X=df.drop('Price',axis=1) # to drop row axis=0 and to drop column axis=1

# %%
y=df['Price']

# %%
X
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population             Income Bin  \
# 0                             4.09     23086.800503  (62749.19, 85225.469]
# 1                             3.09     40173.072174  (62749.19, 85225.469]
# 2                             5.13     36882.159400   (40272.91, 62749.19]
# 3                             3.26     34310.242831  (62749.19, 85225.469]
# 4                             4.23     26354.109472   (40272.91, 62749.19]
# ...                            ...              ...                    ...
# 4995                          3.46     22837.361035   (40272.91, 62749.19]
# 4996                          4.02     25616.115489  (62749.19, 85225.469]
# 4997                          2.13     33266.145490  (62749.19, 85225.469]
# 4998                          5.44     42625.620156  (62749.19, 85225.469]
# 4999                          4.07     46501.283803  (62749.19, 85225.469]
#
#                       Price Bin         Age Bin
# 0      (997189.432, 1487814.82]  (4.363, 6.082]
# 1     (1487814.82, 1978440.207]  (4.363, 6.082]
# 2      (997189.432, 1487814.82]  (4.363, 6.082]
# 3      (997189.432, 1487814.82]    (6.082, 7.8]
# 4      (506564.045, 997189.432]  (4.363, 6.082]
# ...                         ...             ...
# 4995   (997189.432, 1487814.82]    (7.8, 9.519]
# 4996   (997189.432, 1487814.82]    (6.082, 7.8]
# 4997   (997189.432, 1487814.82]    (6.082, 7.8]
# 4998   (997189.432, 1487814.82]  (4.363, 6.082]
# 4999   (997189.432, 1487814.82]  (4.363, 6.082]
#
# [5000 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split # for train we jumble and then it pratices prediction
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=99) # for jumbling use random state=99 and 1/3 of test and 2/3 for train

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 lr.fit(X_train,y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:629, in LinearRegression.fit(self, X, y, sample_weight)
#     624 # Note that neither _rescale_data nor the rest of the fit method of
#     625 # LinearRegression can benefit from in-place operations when X is a
#     626 # sparse matrix. Therefore, let's not copy X when it is sparse.
#     627 copy_X_in_preprocess_data = self.copy_X and not sp.issparse(X)
# --> 629 X, y, X_offset, y_offset, X_scale = _preprocess_data(
#     630     X,
#     631     y,
#     632     fit_intercept=self.fit_intercept,
#     633     copy=copy_X_in_preprocess_data,
#     634     sample_weight=sample_weight,
#     635 )
#     637 if has_sw:
#     638     # Sample weight can be implemented via a simple rescaling. Note
#     639     # that we safely do inplace rescaling when _preprocess_data has
#     640     # already made a copy if requested.
#     641     X, y, sample_weight_sqrt = _rescale_data(
#     642         X, y, sample_weight, inplace=copy_X_in_preprocess_data
#     643     )
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:175, in _preprocess_data(X, y, fit_intercept, copy, copy_y, sample_weight, check_input)
#     172     sample_weight = xp.asarray(sample_weight)
#     174 if check_input:
# --> 175     X = check_array(
#     176         X, copy=copy, accept_sparse=["csr", "csc"], dtype=supported_float_dtypes(xp)
#     177     )
#     178     y = check_array(y, dtype=X.dtype, copy=copy_y, ensure_2d=False)
#     179 else:
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1012, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1010         array = xp.astype(array, dtype, copy=False)
#    1011     else:
# -> 1012         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#    1013 except ComplexWarning as complex_warning:
#    1014     raise ValueError(
#    1015         "Complex data not supported\n{}\n".format(array)
#    1016     ) from complex_warning
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_array_api.py:751, in _asarray_with_order(array, dtype, order, copy, xp, device)
#     749     array = numpy.array(array, order=order, dtype=dtype)
#     750 else:
# --> 751     array = numpy.asarray(array, order=order, dtype=dtype)
#     753 # At this point array is a NumPy ndarray. We convert it to an array
#     754 # container that is consistent with the input's namespace.
#     755 return xp.asarray(array)
#
# TypeError: float() argument must be a string or a real number, not 'pandas._libs.interval.Interval'

# %%
lr.intercept_  #c value

# %%
y_pred=lr.predict(x_test)

# %%
sns.distplot(y_test-y_pred)  #it subtracts prediction and actual value which gives error percentage

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
np.sqrt(mean_squared_error(y_test,y_pred))
y_train_pred=lr.predict(x_train)
np.sqrt(mean_squared_error(y_train,y_train_pred))

# %%
y_test[2:3]

# %%
#Prediction of 2578th row where test-train
1068019.39935159-1168355.3197896334
